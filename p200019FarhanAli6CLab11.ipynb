# %% [markdown]
# ### defining map of Romania

# %%
import heapq

romania_map = {
    'Arad': {'Zerind': 75, 'Timisoara': 118, 'Sibiu': 140},
    'Zerind': {'Arad': 75, 'Oradea': 71},
    'Timisoara': {'Arad': 118, 'Lugoj': 111},
    'Sibiu': {'Arad': 140, 'Oradea': 151, 'Fagaras': 99, 'Rimnicu Vilcea': 80},
    'Oradea': {'Zerind': 71, 'Sibiu': 151},
    'Lugoj': {'Timisoara': 111, 'Mehadia': 70},
    'Fagaras': {'Sibiu': 99, 'Bucharest': 211},
    'Rimnicu Vilcea': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Mehadia': {'Lugoj': 70, 'Drobeta': 75},
    'Drobeta': {'Mehadia': 75, 'Craiova': 120},
    'Craiova': {'Drobeta': 120, 'Rimnicu Vilcea': 146, 'Pitesti': 138},
    'Pitesti': {'Rimnicu Vilcea': 97, 'Craiova': 138, 'Bucharest': 101},
    'Bucharest': {'Fagaras': 211, 'Pitesti': 101}
}

# %% [markdown]
# ### defining heuristic

# %%
heuristic = {
    'Arad': 366,
    'Bucharest': 0,
    'Craiova': 160,
    'Drobeta': 242,
    'Fagaras': 176,
    'Lugoj': 244,
    'Mehadia': 241,
    'Oradea': 380,
    'Pitesti': 100,
    'Rimnicu Vilcea': 193,
    'Sibiu': 253,
    'Timisoara': 329,
    'Zerind': 374
}

# %% [markdown]
# ### A STAR DEFINITION

# %%
def a_star_search(graph, start, goal):
    queue = [(0, start)]
    total_cost = {start: 0}
    path = {start: []}

    while queue:
        current_cost, current_city = heapq.heappop(queue)

        if current_city == goal:
            return path[current_city]

        for neighbor, distance in graph[current_city].items():
            new_cost = total_cost[current_city] + distance
            heuristic_value = heuristic[neighbor]
            total_estimated_cost = new_cost + heuristic_value

            if neighbor not in total_cost or new_cost < total_cost[neighbor]:
                total_cost[neighbor] = new_cost
                path[neighbor] = path[current_city] + [current_city]
                heapq.heappush(queue, (total_estimated_cost, neighbor))

# %% [markdown]
# ### Call the A* search function to find the shortest path between two cities

# %%
 start_cities = ['Arad',
'Zerind',
'Timisoara',
'Sibiu',
'Oradea',
'Lugoj',
'Fagaras',
'Rimnicu Vilcea',
'Mehadia', 
'Drobeta', 
'Craiova',
'Pitesti',
'Bucharest']
    
goal_cities = ['Arad',
'Zerind',
'Timisoara',
'Sibiu',
'Oradea',
'Lugoj',
'Fagaras',
'Rimnicu Vilcea',
'Mehadia', 
'Drobeta', 
'Craiova',
'Pitesti',
'Bucharest']


for i in start_cities:
    for j in goal_cities:
        start_city = i
        goal_city = j
        shortest_path = a_star_search(romania_map, start_city, goal_city)

        if shortest_path is None:
            print("No path found.")
        else:
            print(f"Shortest path from {i} to {j}:", shortest_path)
            print("<----------------------------------------------------->")
# Out:
# Shortest path from Arad to Arad: []
# <----------------------------------------------------->
# Shortest path from Arad to Zerind: ['Arad']
# <----------------------------------------------------->
# Shortest path from Arad to Timisoara: ['Arad']
# <----------------------------------------------------->
# Shortest path from Arad to Sibiu: ['Arad']
# <----------------------------------------------------->
# Shortest path from Arad to Oradea: ['Arad', 'Zerind']
# <----------------------------------------------------->
# Shortest path from Arad to Lugoj: ['Arad', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Arad to Fagaras: ['Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Arad to Rimnicu Vilcea: ['Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Arad to Mehadia: ['Arad', 'Timisoara', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Arad to Drobeta: ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Arad to Craiova: ['Arad', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Arad to Pitesti: ['Arad', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Arad to Bucharest: ['Arad', 'Sibiu', 'Rimnicu Vilcea', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Zerind to Arad: ['Zerind']
# <----------------------------------------------------->
# Shortest path from Zerind to Zerind: []
# <----------------------------------------------------->
# Shortest path from Zerind to Timisoara: ['Zerind', 'Arad']
# <----------------------------------------------------->
# Shortest path from Zerind to Sibiu: ['Zerind', 'Arad']
# <----------------------------------------------------->
# Shortest path from Zerind to Oradea: ['Zerind']
# <----------------------------------------------------->
# Shortest path from Zerind to Lugoj: ['Zerind', 'Arad', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Zerind to Fagaras: ['Zerind', 'Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Zerind to Rimnicu Vilcea: ['Zerind', 'Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Zerind to Mehadia: ['Zerind', 'Arad', 'Timisoara', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Zerind to Drobeta: ['Zerind', 'Arad', 'Timisoara', 'Lugoj', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Zerind to Craiova: ['Zerind', 'Arad', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Zerind to Pitesti: ['Zerind', 'Arad', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Zerind to Bucharest: ['Zerind', 'Arad', 'Sibiu', 'Rimnicu Vilcea', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Timisoara to Arad: ['Timisoara']
# <----------------------------------------------------->
# Shortest path from Timisoara to Zerind: ['Timisoara', 'Arad']
# <----------------------------------------------------->
# Shortest path from Timisoara to Timisoara: []
# <----------------------------------------------------->
# Shortest path from Timisoara to Sibiu: ['Timisoara', 'Arad']
# <----------------------------------------------------->
# Shortest path from Timisoara to Oradea: ['Timisoara', 'Arad', 'Zerind']
# <----------------------------------------------------->
# Shortest path from Timisoara to Lugoj: ['Timisoara']
# <----------------------------------------------------->
# Shortest path from Timisoara to Fagaras: ['Timisoara', 'Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Timisoara to Rimnicu Vilcea: ['Timisoara', 'Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Timisoara to Mehadia: ['Timisoara', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Timisoara to Drobeta: ['Timisoara', 'Lugoj', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Timisoara to Craiova: ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Timisoara to Pitesti: ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Timisoara to Bucharest: ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu Vilcea', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Sibiu to Arad: ['Sibiu']
# <----------------------------------------------------->
# Shortest path from Sibiu to Zerind: ['Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Sibiu to Timisoara: ['Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Sibiu to Sibiu: []
# <----------------------------------------------------->
# Shortest path from Sibiu to Oradea: ['Sibiu']
# <----------------------------------------------------->
# Shortest path from Sibiu to Lugoj: ['Sibiu', 'Arad', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Sibiu to Fagaras: ['Sibiu']
# <----------------------------------------------------->
# Shortest path from Sibiu to Rimnicu Vilcea: ['Sibiu']
# <----------------------------------------------------->
# Shortest path from Sibiu to Mehadia: ['Sibiu', 'Rimnicu Vilcea', 'Craiova', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Sibiu to Drobeta: ['Sibiu', 'Rimnicu Vilcea', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Sibiu to Craiova: ['Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Sibiu to Pitesti: ['Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Sibiu to Bucharest: ['Sibiu', 'Rimnicu Vilcea', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Oradea to Arad: ['Oradea', 'Zerind']
# <----------------------------------------------------->
# Shortest path from Oradea to Zerind: ['Oradea']
# <----------------------------------------------------->
# Shortest path from Oradea to Timisoara: ['Oradea', 'Zerind', 'Arad']
# <----------------------------------------------------->
# Shortest path from Oradea to Sibiu: ['Oradea']
# <----------------------------------------------------->
# Shortest path from Oradea to Oradea: []
# <----------------------------------------------------->
# Shortest path from Oradea to Lugoj: ['Oradea', 'Zerind', 'Arad', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Oradea to Fagaras: ['Oradea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Oradea to Rimnicu Vilcea: ['Oradea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Oradea to Mehadia: ['Oradea', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Oradea to Drobeta: ['Oradea', 'Sibiu', 'Rimnicu Vilcea', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Oradea to Craiova: ['Oradea', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Oradea to Pitesti: ['Oradea', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Oradea to Bucharest: ['Oradea', 'Sibiu', 'Rimnicu Vilcea', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Lugoj to Arad: ['Lugoj', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Lugoj to Zerind: ['Lugoj', 'Timisoara', 'Arad']
# <----------------------------------------------------->
# Shortest path from Lugoj to Timisoara: ['Lugoj']
# <----------------------------------------------------->
# Shortest path from Lugoj to Sibiu: ['Lugoj', 'Timisoara', 'Arad']
# <----------------------------------------------------->
# Shortest path from Lugoj to Oradea: ['Lugoj', 'Timisoara', 'Arad', 'Zerind']
# <----------------------------------------------------->
# Shortest path from Lugoj to Lugoj: []
# <----------------------------------------------------->
# Shortest path from Lugoj to Fagaras: ['Lugoj', 'Timisoara', 'Arad', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Lugoj to Rimnicu Vilcea: ['Lugoj', 'Mehadia', 'Drobeta', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Lugoj to Mehadia: ['Lugoj']
# <----------------------------------------------------->
# Shortest path from Lugoj to Drobeta: ['Lugoj', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Lugoj to Craiova: ['Lugoj', 'Mehadia', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Lugoj to Pitesti: ['Lugoj', 'Mehadia', 'Drobeta', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Lugoj to Bucharest: ['Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Fagaras to Arad: ['Fagaras', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Fagaras to Zerind: ['Fagaras', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Fagaras to Timisoara: ['Fagaras', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Fagaras to Sibiu: ['Fagaras']
# <----------------------------------------------------->
# Shortest path from Fagaras to Oradea: ['Fagaras', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Fagaras to Lugoj: ['Fagaras', 'Sibiu', 'Arad', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Fagaras to Fagaras: []
# <----------------------------------------------------->
# Shortest path from Fagaras to Rimnicu Vilcea: ['Fagaras', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Fagaras to Mehadia: ['Fagaras', 'Sibiu', 'Rimnicu Vilcea', 'Craiova', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Fagaras to Drobeta: ['Fagaras', 'Sibiu', 'Rimnicu Vilcea', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Fagaras to Craiova: ['Fagaras', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Fagaras to Pitesti: ['Fagaras', 'Sibiu', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Fagaras to Bucharest: ['Fagaras']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Arad: ['Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Zerind: ['Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Timisoara: ['Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Sibiu: ['Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Oradea: ['Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Lugoj: ['Rimnicu Vilcea', 'Craiova', 'Drobeta', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Fagaras: ['Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Rimnicu Vilcea: []
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Mehadia: ['Rimnicu Vilcea', 'Craiova', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Drobeta: ['Rimnicu Vilcea', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Craiova: ['Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Pitesti: ['Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Rimnicu Vilcea to Bucharest: ['Rimnicu Vilcea', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Mehadia to Arad: ['Mehadia', 'Lugoj', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Mehadia to Zerind: ['Mehadia', 'Lugoj', 'Timisoara', 'Arad']
# <----------------------------------------------------->
# Shortest path from Mehadia to Timisoara: ['Mehadia', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Mehadia to Sibiu: ['Mehadia', 'Drobeta', 'Craiova', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Mehadia to Oradea: ['Mehadia', 'Lugoj', 'Timisoara', 'Arad', 'Zerind']
# <----------------------------------------------------->
# Shortest path from Mehadia to Lugoj: ['Mehadia']
# <----------------------------------------------------->
# Shortest path from Mehadia to Fagaras: ['Mehadia', 'Drobeta', 'Craiova', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Mehadia to Rimnicu Vilcea: ['Mehadia', 'Drobeta', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Mehadia to Mehadia: []
# <----------------------------------------------------->
# Shortest path from Mehadia to Drobeta: ['Mehadia']
# <----------------------------------------------------->
# Shortest path from Mehadia to Craiova: ['Mehadia', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Mehadia to Pitesti: ['Mehadia', 'Drobeta', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Mehadia to Bucharest: ['Mehadia', 'Drobeta', 'Craiova', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Drobeta to Arad: ['Drobeta', 'Mehadia', 'Lugoj', 'Timisoara']
# <----------------------------------------------------->
# Shortest path from Drobeta to Zerind: ['Drobeta', 'Mehadia', 'Lugoj', 'Timisoara', 'Arad']
# <----------------------------------------------------->
# Shortest path from Drobeta to Timisoara: ['Drobeta', 'Mehadia', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Drobeta to Sibiu: ['Drobeta', 'Craiova', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Drobeta to Oradea: ['Drobeta', 'Craiova', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Drobeta to Lugoj: ['Drobeta', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Drobeta to Fagaras: ['Drobeta', 'Craiova', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Drobeta to Rimnicu Vilcea: ['Drobeta', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Drobeta to Mehadia: ['Drobeta']
# <----------------------------------------------------->
# Shortest path from Drobeta to Drobeta: []
# <----------------------------------------------------->
# Shortest path from Drobeta to Craiova: ['Drobeta']
# <----------------------------------------------------->
# Shortest path from Drobeta to Pitesti: ['Drobeta', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Drobeta to Bucharest: ['Drobeta', 'Craiova', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Craiova to Arad: ['Craiova', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Craiova to Zerind: ['Craiova', 'Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Craiova to Timisoara: ['Craiova', 'Drobeta', 'Mehadia', 'Lugoj']
# <----------------------------------------------------->
# Shortest path from Craiova to Sibiu: ['Craiova', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Craiova to Oradea: ['Craiova', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Craiova to Lugoj: ['Craiova', 'Drobeta', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Craiova to Fagaras: ['Craiova', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Craiova to Rimnicu Vilcea: ['Craiova']
# <----------------------------------------------------->
# Shortest path from Craiova to Mehadia: ['Craiova', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Craiova to Drobeta: ['Craiova']
# <----------------------------------------------------->
# Shortest path from Craiova to Craiova: []
# <----------------------------------------------------->
# Shortest path from Craiova to Pitesti: ['Craiova']
# <----------------------------------------------------->
# Shortest path from Craiova to Bucharest: ['Craiova', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Pitesti to Arad: ['Pitesti', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Pitesti to Zerind: ['Pitesti', 'Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Pitesti to Timisoara: ['Pitesti', 'Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Pitesti to Sibiu: ['Pitesti', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Pitesti to Oradea: ['Pitesti', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Pitesti to Lugoj: ['Pitesti', 'Craiova', 'Drobeta', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Pitesti to Fagaras: ['Pitesti', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Pitesti to Rimnicu Vilcea: ['Pitesti']
# <----------------------------------------------------->
# Shortest path from Pitesti to Mehadia: ['Pitesti', 'Craiova', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Pitesti to Drobeta: ['Pitesti', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Pitesti to Craiova: ['Pitesti']
# <----------------------------------------------------->
# Shortest path from Pitesti to Pitesti: []
# <----------------------------------------------------->
# Shortest path from Pitesti to Bucharest: ['Pitesti']
# <----------------------------------------------------->
# Shortest path from Bucharest to Arad: ['Bucharest', 'Pitesti', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Bucharest to Zerind: ['Bucharest', 'Pitesti', 'Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Bucharest to Timisoara: ['Bucharest', 'Pitesti', 'Rimnicu Vilcea', 'Sibiu', 'Arad']
# <----------------------------------------------------->
# Shortest path from Bucharest to Sibiu: ['Bucharest', 'Pitesti', 'Rimnicu Vilcea']
# <----------------------------------------------------->
# Shortest path from Bucharest to Oradea: ['Bucharest', 'Pitesti', 'Rimnicu Vilcea', 'Sibiu']
# <----------------------------------------------------->
# Shortest path from Bucharest to Lugoj: ['Bucharest', 'Pitesti', 'Craiova', 'Drobeta', 'Mehadia']
# <----------------------------------------------------->
# Shortest path from Bucharest to Fagaras: ['Bucharest']
# <----------------------------------------------------->
# Shortest path from Bucharest to Rimnicu Vilcea: ['Bucharest', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Bucharest to Mehadia: ['Bucharest', 'Pitesti', 'Craiova', 'Drobeta']
# <----------------------------------------------------->
# Shortest path from Bucharest to Drobeta: ['Bucharest', 'Pitesti', 'Craiova']
# <----------------------------------------------------->
# Shortest path from Bucharest to Craiova: ['Bucharest', 'Pitesti']
# <----------------------------------------------------->
# Shortest path from Bucharest to Pitesti: ['Bucharest']
# <----------------------------------------------------->
# Shortest path from Bucharest to Bucharest: []
# <----------------------------------------------------->
